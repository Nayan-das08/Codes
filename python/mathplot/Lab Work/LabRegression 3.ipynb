# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import numpy as np
def stocashtic_gradient_descent(X,y,theta,learning_rate=0.01,iterations=10):
    '''
    X=Matrix of X with added bias units
    y=Vector of Y
    some comments are left
    '''
    m=len(y)
    cost_history=np.zeros(iterations)
    for it in range(iterations):
        cost =0.0
        for i in range(m):
            rand_ind=np.random.randint(0,m)
            X_i=X[rand_ind,:].reshape(1,X.shape[1])
            y_i=y[rand_ind].reshape(1,1)
            prediction=np.dot(X_i,theta)
            
            theta=theta-(1/m)*learning_rate*(X_i.T.dot((prediction -y_i)))
            cost+=cal_cost(theta,X_i,y_i)
        cost_history[it] = cost
    return theta, cost_history

lr = 0.01
n_iter = 1000

theta = np.random.randn(2,1)

X_b = np.c_(np.ones((len(X), 1)), X)

theta, cost_history, theta_history = stocashtic_gradient_descent(X_b, y, theta, lr, n_iter)


print(f"theta0 = {'%.3f'%theta[0][0]}, theta1 = {'%.3f'%theta[1][0]}")
print(f"Final cost or Minimum Squared Error = {cost_history[-1]}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-f2fe2f1cac33> in <module>()
#      26 theta = np.random.randn(2,1)
#      27
# ---> 28 X_b = np.c_(np.ones((len(X), 1)), X)
#      29
#      30 theta, cost_history, theta_history = stocashtic_gradient_descent(X_b, y, theta, lr, n_iter)
#
# NameError: name 'X' is not defined
