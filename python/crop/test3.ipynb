# %%
import pandas as pd
import matplotlib.pyplot as plt
import regression as reg
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import numpy as np

# %%
df = pd.read_csv('eco-emp.csv')
df.head()
# Out:
#    year  deflation     gnp  unemployed  military  over 14  employed
# 0  1947       83.0  234289        2356      1590   107608     60323
# 1  1948       88.5  259426        2326      1456   108632     61122
# 2  1949       88.2  258054        3682      1616   109773     60171
# 3  1950       89.5  284599        3351      1650   110929     61187
# 4  1951       96.2  328975        2099      3099   112075     63221

# %%
plt.scatter(df['gnp'],df['employed'])

# %%
df['new'] = 0
df
# Out:
#     year  deflation     gnp  unemployed  military  over 14  employed  new
# 0   1947       83.0  234289        2356      1590   107608     60323    0
# 1   1948       88.5  259426        2326      1456   108632     61122    0
# 2   1949       88.2  258054        3682      1616   109773     60171    0
# 3   1950       89.5  284599        3351      1650   110929     61187    0
# 4   1951       96.2  328975        2099      3099   112075     63221    0
# 5   1952       98.1  346999        1932      3594   113270     63639    0
# 6   1953       99.0  365385        1870      3547   115094     64989    0
# 7   1954      100.0  363112        3578      3350   116219     63761    0
# 8   1955      101.2  397469        2904      3048   117388     66019    0
# 9   1956      104.6  419180        2822      2857   118734     67857    0
# 10  1957      108.4  442769        2936      2798   120445     68169    0
# 11  1958      110.8  444546        4681      2637   121950     66513    0
# 12  1959      112.6  482704        3813      2552   123366     68655    0
# 13  1960      114.2  502601        3931      2514   125368     69564    0
# 14  1961      115.7  518173        4806      2572   127852     69331    0
# 15  1962      116.9  554894        4007      2827   130081     70561    0

# %%
x = 60000
for i in df.index:
    for j in range(11):
        if int(df['employed'][i]) >= x+(j*1000) and int(df['employed'][i]) < x+(j*1000)+1000:
            df['new'][i] = j
df
# Out:
# C:\Users\NayanPC\AppData\Local\Temp/ipykernel_13272/647034309.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['new'][i] = j
#     year  deflation     gnp  unemployed  military  over 14  employed  new
# 0   1947       83.0  234289        2356      1590   107608     60323    0
# 1   1948       88.5  259426        2326      1456   108632     61122    1
# 2   1949       88.2  258054        3682      1616   109773     60171    0
# 3   1950       89.5  284599        3351      1650   110929     61187    1
# 4   1951       96.2  328975        2099      3099   112075     63221    3
# 5   1952       98.1  346999        1932      3594   113270     63639    3
# 6   1953       99.0  365385        1870      3547   115094     64989    4
# 7   1954      100.0  363112        3578      3350   116219     63761    3
# 8   1955      101.2  397469        2904      3048   117388     66019    6
# 9   1956      104.6  419180        2822      2857   118734     67857    7
# 10  1957      108.4  442769        2936      2798   120445     68169    8
# 11  1958      110.8  444546        4681      2637   121950     66513    6
# 12  1959      112.6  482704        3813      2552   123366     68655    8
# 13  1960      114.2  502601        3931      2514   125368     69564    9
# 14  1961      115.7  518173        4806      2572   127852     69331    9
# 15  1962      116.9  554894        4007      2827   130081     70561   10

# %%
x = 60000
for j in range(11):
    print(x+(j*1000), x+(j*1000)+1000)
# Out:
# 60000 61000
# 61000 62000
# 62000 63000
# 63000 64000
# 64000 65000
# 65000 66000
# 66000 67000
# 67000 68000
# 68000 69000
# 69000 70000
# 70000 71000
