# %% [markdown]
# consider the below given data and write the commands for the following (the output to display a single value)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame({'Qty1':[30,40,60,70], 'Qty2':[30,90,40,50], 'Qty3':[60,40,30,50]})
df
# Out:
#    Qty1  Qty2  Qty3
# 0    30    30    60
# 1    40    90    40
# 2    60    40    30
# 3    70    50    50

# %%
np.multiply(df.Qty1, df.Qty2)
# Out:
# 0     900
# 1    3600
# 2    2400
# 3    3500
# dtype: int64

# %%
np.dot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9592/2294643113.py in <module>
# ----> 1 df.dot()
#
# TypeError: dot() missing 1 required positional argument: 'other'

# %%
df.prod(axis=1)
# Out:
# 0      810000
# 1    12960000
# 2     5760000
# 3    12250000
# dtype: int64

# %%
df.Qty1*df.Qty2*df.Qty3
# Out:
# 0      810000
# 1    12960000
# 2     5760000
# 3    12250000
# dtype: int64

# %%
df.mean()
# Out:
# Qty1      50.0
# Qty2      52.5
# Qty3    2600.0
# dtype: float64

# %% [markdown]
# ## 1. find the mean of middle row / row 2

# %%
df.loc[2].mean()
# Out:
# 43.333333333333336

# %% [markdown]
# ## 2. add a column (Qty4) to the table (sum of previous three columns)

# %%
df['Qty1'] + df['Qty2']
# Out:
# 0     60
# 1    130
# 2    100
# 3    120
# dtype: int64

# %%
Qty4 = df.sum(axis=1)

# %%
df['Qty4'] = Qty4
df
# Out:
#    Qty1  Qty2  Qty3  Qty4
# 0    30    30    60   120
# 1    40    90    40   170
# 2    60    40    30   130
# 3    70    50    50   170

# %% [markdown]
# ## 3. count the number of values in Qty4 which is more than 175

# %%
len(df.loc[df.Qty4 > 130])
# Out:
# 2
