# %% [markdown]
# # Nayan Ranjan Das | A2305220148 | 5CSE2
# # Lab 1
# August 8, 2022

# %% [markdown]
# ---

# %% [markdown]
# ## importing required Python libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## reading the datasets

# %%
cust_df   = pd.read_csv('global_sales_data/cust_dimen.csv')
market_df = pd.read_csv('global_sales_data/market_fact.csv')
orders_df = pd.read_csv('global_sales_data/orders_dimen.csv')
prod_df   = pd.read_csv('global_sales_data/prod_dimen.csv')
shoip_df  = pd.read_csv('global_sales_data/shipping_dimen.csv')

# %%
cust_df.head()
# Out:
#         Customer_Name Province   Region Customer_Segment Cust_id
# 0  MUHAMMED MACINTYRE  NUNAVUT  NUNAVUT   SMALL BUSINESS  Cust_1
# 1        BARRY FRENCH  NUNAVUT  NUNAVUT         CONSUMER  Cust_2
# 2       CLAY ROZENDAL  NUNAVUT  NUNAVUT        CORPORATE  Cust_3
# 3      CARLOS SOLTERO  NUNAVUT  NUNAVUT         CONSUMER  Cust_4
# 4        CARL JACKSON  NUNAVUT  NUNAVUT        CORPORATE  Cust_5

# %% [markdown]
# ## selection of rows and columns using `loc` and `iloc`

# %%
cust_df.iloc[3,0]
# Out:
# 'CARLOS SOLTERO'

# %%
cust_df.loc[3,'Customer_Name']
# Out:
# 'CARLOS SOLTERO'

# %%
cust_df.iloc[[2,3],:]
# Out:
#     Customer_Name Province   Region Customer_Segment Cust_id
# 2   CLAY ROZENDAL  NUNAVUT  NUNAVUT        CORPORATE  Cust_3
# 3  CARLOS SOLTERO  NUNAVUT  NUNAVUT         CONSUMER  Cust_4

# %%
cust_df.iloc[:5,:]
# Out:
#         Customer_Name Province   Region Customer_Segment Cust_id
# 0  MUHAMMED MACINTYRE  NUNAVUT  NUNAVUT   SMALL BUSINESS  Cust_1
# 1        BARRY FRENCH  NUNAVUT  NUNAVUT         CONSUMER  Cust_2
# 2       CLAY ROZENDAL  NUNAVUT  NUNAVUT        CORPORATE  Cust_3
# 3      CARLOS SOLTERO  NUNAVUT  NUNAVUT         CONSUMER  Cust_4
# 4        CARL JACKSON  NUNAVUT  NUNAVUT        CORPORATE  Cust_5

# %% [markdown]
# ### note:
# - `loc` gives values including the last index
# - `iloc` doesn't

# %%
cust_df.loc[:5,:]
# Out:
#         Customer_Name Province   Region Customer_Segment Cust_id
# 0  MUHAMMED MACINTYRE  NUNAVUT  NUNAVUT   SMALL BUSINESS  Cust_1
# 1        BARRY FRENCH  NUNAVUT  NUNAVUT         CONSUMER  Cust_2
# 2       CLAY ROZENDAL  NUNAVUT  NUNAVUT        CORPORATE  Cust_3
# 3      CARLOS SOLTERO  NUNAVUT  NUNAVUT         CONSUMER  Cust_4
# 4        CARL JACKSON  NUNAVUT  NUNAVUT        CORPORATE  Cust_5
# 5      MONICA FEDERLE  NUNAVUT  NUNAVUT        CORPORATE  Cust_6

# %%
cust_df.loc[5:8]
# Out:
#      Customer_Name Province   Region Customer_Segment Cust_id
# 5   MONICA FEDERLE  NUNAVUT  NUNAVUT        CORPORATE  Cust_6
# 6  DOROTHY BADDERS  NUNAVUT  NUNAVUT      HOME OFFICE  Cust_7
# 7  NEOLA SCHNEIDER  NUNAVUT  NUNAVUT      HOME OFFICE  Cust_8
# 8      CARLOS DALY  NUNAVUT  NUNAVUT      HOME OFFICE  Cust_9

# %%
cust_df.iloc[[3,7,8]]
# Out:
#      Customer_Name Province   Region Customer_Segment Cust_id
# 3   CARLOS SOLTERO  NUNAVUT  NUNAVUT         CONSUMER  Cust_4
# 7  NEOLA SCHNEIDER  NUNAVUT  NUNAVUT      HOME OFFICE  Cust_8
# 8      CARLOS DALY  NUNAVUT  NUNAVUT      HOME OFFICE  Cust_9

# %%
market_df.iloc[3,2]
# Out:
# 'SHP_7625'

# %%
market_df.iloc[[3,5,6]]
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 5  Ord_5446   Prod_6  SHP_7608  Cust_1818   164.02      0.03              23
# 6    Ord_31  Prod_12    SHP_41    Cust_26    14.76      0.01               5
#
#    Profit  Shipping_Cost  Product_Base_Margin
# 3  729.34          14.30                 0.37
# 5  -47.64           6.15                 0.37
# 6    1.32           0.50                 0.36

# %%
market_df.loc[[3*2]]
# Out:
#    Ord_id  Prod_id Ship_id  Cust_id  Sales  Discount  Order_Quantity  Profit  \
# 6  Ord_31  Prod_12  SHP_41  Cust_26  14.76      0.01               5    1.32
#
#    Shipping_Cost  Product_Base_Margin
# 6            0.5                 0.36

# %% [markdown]
# ## changing index of dataframe

# %%
market_order = market_df.set_index('Ord_id')

# %%
market_order.loc[['Ord_5406','Ord_5485'],]
# Out:
#           Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# Ord_id
# Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#            Profit  Shipping_Cost  Product_Base_Margin
# Ord_id
# Ord_5406     4.56           0.93                 0.54
# Ord_5485  1219.87          26.30                 0.38

# %%
market_df['Sales']
# Out:
# 0        136.8100
# 1         42.2700
# 2       4701.6900
# 3       2337.8900
# 4       4233.1500
#           ...
# 8394    2841.4395
# 8395     127.1600
# 8396     243.0500
# 8397    3872.8700
# 8398     603.6900
# Name: Sales, Length: 8399, dtype: float64

# %% [markdown]
# ## Slicing and dicing dataframe

# %%
market_df['Sales'] > 2000
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4        True
#         ...
# 8394     True
# 8395    False
# 8396    False
# 8397     True
# 8398    False
# Name: Sales, Length: 8399, dtype: bool

# %%
market_df.Discount.describe()
# Out:
# count    8399.000000
# mean        0.049671
# std         0.031823
# min         0.000000
# 25%         0.020000
# 50%         0.050000
# 75%         0.080000
# max         0.250000
# Name: Discount, dtype: float64

# %%
market_df.loc[market_df.Sales > 2000]
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# 7     Ord_4725   Prod_4  SHP_6593  Cust_1641  3410.1575      0.10
# 10    Ord_4743   Prod_2  SHP_6615  Cust_1641  4072.0100      0.01
# ...        ...      ...       ...        ...        ...       ...
# 8371  Ord_2624   Prod_4  SHP_3591  Cust_1006  4924.1350      0.07
# 8381  Ord_2696   Prod_4  SHP_3691  Cust_1006  2836.0505      0.01
# 8383  Ord_2722   Prod_1  SHP_3731  Cust_1006  3508.3300      0.04
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 2                 26  1148.90           2.50                 0.59
# ...

# %%
market_df.loc[(market_df.Sales > 2000) & (market_df.Sales < 3000) & (market_df.Profit > 100)]
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 81    Ord_5205   Prod_4  SHP_7274  Cust_1749  2546.5235      0.09
# 109    Ord_139  Prod_17   SHP_186    Cust_45  2671.2100      0.06
# 110    Ord_239   Prod_4   SHP_332    Cust_45  2157.3085      0.00
# 141   Ord_1673  Prod_17  SHP_2314   Cust_498  2027.5500      0.04
# ...        ...      ...       ...        ...        ...       ...
# 8338  Ord_2107   Prod_2  SHP_2882   Cust_785  2409.9600      0.07
# 8350  Ord_3570   Prod_4  SHP_4942  Cust_1266  2094.9780      0.06
# 8354  Ord_3592   Prod_4  SHP_4973  Cust_1266  2614.3705      0.07
# 8381  Ord_2696   Prod_4  SHP_3691  Cust_1006  2836.0505      0.01
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
#
#       Order_Quantity  Profit  Shipping_Cost  Product_Base_Margin
# 3                 43  729.34          14.30                 0.37
# ...

# %%
market_df.loc[(market_df.Discount > 0.15) | market_df.Sales > 2000]
# Out:
# Empty DataFrame
# Columns: [Ord_id, Prod_id, Ship_id, Cust_id, Sales, Discount, Order_Quantity, Profit, Shipping_Cost, Product_Base_Margin]
# Index: []

# %%
market_df.loc[~(market_df.Sales < 3000)]
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id       Sales  Discount  \
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818   4701.6900      0.00
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818   4233.1500      0.08
# 7     Ord_4725   Prod_4  SHP_6593  Cust_1641   3410.1575      0.10
# 10    Ord_4743   Prod_2  SHP_6615  Cust_1641   4072.0100      0.01
# 13    Ord_2207  Prod_11  SHP_3093   Cust_839   3364.2480      0.10
# ...        ...      ...       ...        ...         ...       ...
# 8366  Ord_3593   Prod_3  SHP_4974  Cust_1274  12073.0600      0.03
# 8367  Ord_3593  Prod_15  SHP_4975  Cust_1274   6685.0500      0.09
# 8371  Ord_2624   Prod_4  SHP_3591  Cust_1006   4924.1350      0.07
# 8383  Ord_2722   Prod_1  SHP_3731  Cust_1006   3508.3300      0.04
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798   3872.8700      0.03
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 2                 26  1148.90           2.50                 0.59
# ...
