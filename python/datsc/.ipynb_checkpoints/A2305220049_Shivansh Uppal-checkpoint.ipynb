# %%
import pandas as pd
import numpy as np

# %%
mark1=pd.read_csv(r"C:\programming languages\Data science\cust_dimen.csv")
mark2=pd.read_csv(r"C:\programming languages\Data science\prod_dimen.csv")
mark3=pd.read_csv(r"C:\programming languages\Data science\shipping_dimen.csv")
mark4=pd.read_csv(r"C:\programming languages\Data science\orders_dimen.csv")
mark5=pd.read_csv(r"C:\programming languages\Data science\market_fact.csv")

# %%
mark1.head()
# Out:
#         Customer_Name Province   Region Customer_Segment Cust_id
# 0  MUHAMMED MACINTYRE  NUNAVUT  NUNAVUT   SMALL BUSINESS  Cust_1
# 1        BARRY FRENCH  NUNAVUT  NUNAVUT         CONSUMER  Cust_2
# 2       CLAY ROZENDAL  NUNAVUT  NUNAVUT        CORPORATE  Cust_3
# 3      CARLOS SOLTERO  NUNAVUT  NUNAVUT         CONSUMER  Cust_4
# 4        CARL JACKSON  NUNAVUT  NUNAVUT        CORPORATE  Cust_5

# %%
mark2.head()
# Out:
#   Product_Category            Product_Sub_Category Prod_id
# 0  OFFICE SUPPLIES          STORAGE & ORGANIZATION  Prod_1
# 1  OFFICE SUPPLIES                      APPLIANCES  Prod_2
# 2  OFFICE SUPPLIES  BINDERS AND BINDER ACCESSORIES  Prod_3
# 3       TECHNOLOGY    TELEPHONES AND COMMUNICATION  Prod_4
# 4        FURNITURE              OFFICE FURNISHINGS  Prod_5

# %%
mark3.head()
# Out:
#    Order_ID       Ship_Mode   Ship_Date Ship_id
# 0         3     REGULAR AIR  20-10-2010   SHP_1
# 1       293  DELIVERY TRUCK  02-10-2012   SHP_2
# 2       293     REGULAR AIR  03-10-2012   SHP_3
# 3       483     REGULAR AIR  12-07-2011   SHP_4
# 4       515     REGULAR AIR  30-08-2010   SHP_5

# %%
mark4.head()
# Out:
#    Order_ID  Order_Date Order_Priority Ord_id
# 0         3  13-10-2010            LOW  Ord_1
# 1       293  01-10-2012           HIGH  Ord_2
# 2       483  10-07-2011           HIGH  Ord_3
# 3       515  28-08-2010  NOT SPECIFIED  Ord_4
# 4       613  17-06-2011           HIGH  Ord_5

# %%
mark5.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %% [markdown]
# SELECT ALL ORDERS AND SALES OF CUSTOMER SEGMENT CORPORATE

# %%
df1=pd.merge(mark1,mark5,on='Cust_id')

# %%
df1
# Out:
#            Customer_Name Province   Region Customer_Segment    Cust_id  \
# 0     MUHAMMED MACINTYRE  NUNAVUT  NUNAVUT   SMALL BUSINESS     Cust_1
# 1           BARRY FRENCH  NUNAVUT  NUNAVUT         CONSUMER     Cust_2
# 2           BARRY FRENCH  NUNAVUT  NUNAVUT         CONSUMER     Cust_2
# 3          CLAY ROZENDAL  NUNAVUT  NUNAVUT        CORPORATE     Cust_3
# 4          CLAY ROZENDAL  NUNAVUT  NUNAVUT        CORPORATE     Cust_3
# ...                  ...      ...      ...              ...        ...
# 8394     GRANT DONATELLI  ALBERTA     WEST         CONSUMER  Cust_1831
# 8395     GRANT DONATELLI  ALBERTA     WEST         CONSUMER  Cust_1831
# 8396          MICK BROWN  ALBERTA     WEST         CONSUMER  Cust_1832
# 8397          MICK BROWN  ALBERTA     WEST         CONSUMER  Cust_1832
# 8398          MICK BROWN  ALBERTA     WEST         CONSUMER  Cust_1832
#
#         Ord_id  Prod_id   Ship_id       Sales  Discount  Order_Quantity  \
# ...

# %%
df1.loc[df1.Customer_Segment=='CORPORATE',['Ord_id','Sales']]
# Out:
#         Ord_id       Sales
# 3        Ord_3   4965.7595
# 4       Ord_35   1285.3700
# 10       Ord_5    905.0800
# 11       Ord_5     93.5400
# 12       Ord_6   2781.8200
# ...        ...         ...
# 8389  Ord_3024   5347.9875
# 8390  Ord_5499   5126.4180
# 8391  Ord_5500     82.1200
# 8392  Ord_5504  10071.0900
# 8393  Ord_5503   1041.6600
#
# [3076 rows x 2 columns]

# %%
df1.loc[(df1.Customer_Segment=='HOME OFFICE') & (df1.Profit>500)]
# Out:
#         Customer_Name               Province                 Region  \
# 16    NEOLA SCHNEIDER                NUNAVUT                NUNAVUT
# 33       ANNIE CYPRUS                NUNAVUT                NUNAVUT
# 106          JOY BELL  NORTHWEST TERRITORIES  NORTHWEST TERRITORIES
# 107          JOY BELL  NORTHWEST TERRITORIES  NORTHWEST TERRITORIES
# 179      CARL JACKSON  NORTHWEST TERRITORIES  NORTHWEST TERRITORIES
# ...               ...                    ...                    ...
# 8278   ANDREW ROBERTS                ALBERTA                   WEST
# 8335         SHUI TOM                ALBERTA                   WEST
# 8336         SHUI TOM                ALBERTA                   WEST
# 8337         SHUI TOM                ALBERTA                   WEST
# 8344     FRANK HAWLEY                ALBERTA                   WEST
#
#      Customer_Segment    Cust_id    Ord_id  Prod_id   Ship_id       Sales  \
# 16        HOME OFFICE     Cust_8    Ord_11   Prod_5    SHP_14   1815.4900
# ...

# %%
df1.loc[(df1.Customer_Name=='ALEX AVILA') & (df1.Profit>500) & (df1.Customer_Segment=='HOME OFFICE')]
# Out:
#     Customer_Name          Province Region Customer_Segment   Cust_id  \
# 943    ALEX AVILA  BRITISH COLUMBIA   WEST      HOME OFFICE  Cust_209
# 945    ALEX AVILA  BRITISH COLUMBIA   WEST      HOME OFFICE  Cust_209
#
#       Ord_id Prod_id  Ship_id      Sales  Discount  Order_Quantity  Profit  \
# 943  Ord_597  Prod_4  SHP_816  4283.2350      0.10              44  676.13
# 945  Ord_597  Prod_4  SHP_816  4374.6865      0.05              43  973.16
#
#      Shipping_Cost  Product_Base_Margin
# 943           8.80                 0.59
# 945           8.08                 0.57

# %%
df1.loc[(df1.Sales>=300) & (df1.Profit>1000)]
# Out:
#         Customer_Name               Province                 Region  \
# 3       CLAY ROZENDAL                NUNAVUT                NUNAVUT
# 33       ANNIE CYPRUS                NUNAVUT                NUNAVUT
# 46       EDWARD HOOKS                NUNAVUT                NUNAVUT
# 72      GRANT CARROLL                NUNAVUT                NUNAVUT
# 88    SYLVIA FOULSTON  NORTHWEST TERRITORIES  NORTHWEST TERRITORIES
# ...               ...                    ...                    ...
# 8350    AARON BERGMAN                ALBERTA                   WEST
# 8376         SHUI TOM                ALBERTA                   WEST
# 8389    JASON FORTUNE                ALBERTA                   WEST
# 8390    JASON FORTUNE                ALBERTA                   WEST
# 8392     HARRY GREENE                ALBERTA                   WEST
#
#      Customer_Segment    Cust_id    Ord_id  Prod_id   Ship_id       Sales  \
# 3           CORPORATE     Cust_3     Ord_3   Prod_4     SHP_4   4965.7595
# ...

# %%
new=pd.merge(df1,mark2,on='Prod_id')

# %%
new.loc[(new.Product_Category=='OFFICE SUPPLIES') & (new.Customer_Segment=='CORPORATE') ]
# Out:
#        Customer_Name               Province                 Region  \
# 2       CARL JACKSON                NUNAVUT                NUNAVUT
# 3     MONICA FEDERLE                NUNAVUT                NUNAVUT
# 6        BRYAN DAVIS  NORTHWEST TERRITORIES  NORTHWEST TERRITORIES
# 7        ALAN BARNES  NORTHWEST TERRITORIES  NORTHWEST TERRITORIES
# 8       JAMIE KUNITZ  NORTHWEST TERRITORIES  NORTHWEST TERRITORIES
# ...              ...                    ...                    ...
# 8050     CHUCK CLARK                ALBERTA                   WEST
# 8052   MARIA ZETTNER                ALBERTA                   WEST
# 8057  KELLY WILLIAMS                ALBERTA                   WEST
# 8058     RUBEN DARTT                ALBERTA                   WEST
# 8060   AARON BERGMAN                ALBERTA                   WEST
#
#      Customer_Segment    Cust_id    Ord_id  Prod_id   Ship_id    Sales  \
# 2           CORPORATE     Cust_5     Ord_5   Prod_1     SHP_7   905.08
# ...

# %%
new2=pd.merge(new,mark3,on='Ship_id')

# %%
new2
# Out:
#            Customer_Name Province   Region Customer_Segment    Cust_id  \
# 0     MUHAMMED MACINTYRE  NUNAVUT  NUNAVUT   SMALL BUSINESS     Cust_1
# 1         CARLOS SOLTERO  NUNAVUT  NUNAVUT         CONSUMER     Cust_4
# 2           CARL JACKSON  NUNAVUT  NUNAVUT        CORPORATE     Cust_5
# 3         MONICA FEDERLE  NUNAVUT  NUNAVUT        CORPORATE     Cust_6
# 4          NICOLE HANSEN  NUNAVUT  NUNAVUT   SMALL BUSINESS    Cust_24
# ...                  ...      ...      ...              ...        ...
# 8394            SHUI TOM  ALBERTA     WEST      HOME OFFICE  Cust_1816
# 8395        FRANK HAWLEY  ALBERTA     WEST      HOME OFFICE  Cust_1817
# 8396       AARON BERGMAN  ALBERTA     WEST        CORPORATE  Cust_1818
# 8397        ADRIAN SHAMI  ALBERTA     WEST         CONSUMER  Cust_1820
# 8398        HARRY GREENE  ALBERTA     WEST        CORPORATE  Cust_1830
#
#         Ord_id  Prod_id   Ship_id     Sales  Discount  Order_Quantity  \
# ...

# %%
new3=pd.merge(new2,mark4,on='Ord_id')

# %%
new3
# Out:
#            Customer_Name Province   Region Customer_Segment    Cust_id  \
# 0     MUHAMMED MACINTYRE  NUNAVUT  NUNAVUT   SMALL BUSINESS     Cust_1
# 1         CARLOS SOLTERO  NUNAVUT  NUNAVUT         CONSUMER     Cust_4
# 2           CARL JACKSON  NUNAVUT  NUNAVUT        CORPORATE     Cust_5
# 3           CARL JACKSON  NUNAVUT  NUNAVUT        CORPORATE     Cust_5
# 4         MONICA FEDERLE  NUNAVUT  NUNAVUT        CORPORATE     Cust_6
# ...                  ...      ...      ...              ...        ...
# 8394       BRENDAN SWEED  ALBERTA     WEST         CONSUMER  Cust_1804
# 8395  CHRISTOPHER CONANT  ALBERTA     WEST      HOME OFFICE  Cust_1814
# 8396       AARON BERGMAN  ALBERTA     WEST        CORPORATE  Cust_1818
# 8397        ADRIAN SHAMI  ALBERTA     WEST         CONSUMER  Cust_1820
# 8398        HARRY GREENE  ALBERTA     WEST        CORPORATE  Cust_1830
#
#         Ord_id  Prod_id   Ship_id     Sales  Discount  ...  Shipping_Cost  \
# ...

# %%
#prepare a dataframe with three columns: NAME, AGE, GENDER

data1=pd.DataFrame({"Name": ['Aman','Joy','Rahmi','Saif'], "Age": [20,21,22,23],"Gender": ['M','M','F','M']})

# %%
data1
# Out:
#     Name  Age Gender
# 0   Aman   20      M
# 1    Joy   21      M
# 2  Rahmi   22      F
# 3   Saif   23      M

# %%
#prepare a dataframe with three columns

data2=pd.DataFrame({"Name": ['Akhil','Aabha','Preeti'], "Age":[30,31,32], "Gender": ['M','F','F']})

# %%
data4=pd.concat([data1,data2],axis=0)

# %%
data4
# Out:
#      Name  Age Gender
# 0    Aman   20      M
# 1     Joy   21      M
# 2   Rahmi   22      F
# 3    Saif   23      M
# 0   Akhil   30      M
# 1   Aabha   31      F
# 2  Preeti   32      F

# %%
df2=pd.DataFrame({"School": ['A','B','C','D'], "Graduation_name":[67,98,78,89]})

# %%
data3=pd.concat([data1,df2],axis=1)

# %%
data3
# Out:
#     Name  Age Gender School  Graduation_name
# 0   Aman   20      M      A               67
# 1    Joy   21      M      B               98
# 2  Rahmi   22      F      C               78
# 3   Saif   23      M      D               89

# %%
match=pd.DataFrame({"Name": ['CSK','RR','TT','MI','KKR','RCB','DC'], "Match_played": [20,21,22,19,18,23,17], "Match_won": [15,16,17,18,10,0,6]})

# %%
match
# Out:
#   Name  Match_played  Match_won
# 0  CSK            20         15
# 1   RR            21         16
# 2   TT            22         17
# 3   MI            19         18
# 4  KKR            18         10
# 5  RCB            23          0
# 6   DC            17          6

# %%
match2=pd.DataFrame({"Name": ['CSK','RR','TT','MI','KKR','RCB','DC','KXIP'], "Match_played": [21,22,23,20,19,24,18,19], "Match_won": [16,17,16,19,11,1,7,8]})

# %%
match2
# Out:
#    Name  Match_played  Match_won
# 0   CSK            21         16
# 1    RR            22         17
# 2    TT            23         16
# 3    MI            20         19
# 4   KKR            19         11
# 5   RCB            24          1
# 6    DC            18          7
# 7  KXIP            19          8

# %%
match.set_index('Name',inplace=True)
match2.set_index('Name',inplace=True)

# %%
total=match+match2

# %%
total
# Out:
#       Match_played  Match_won
# Name
# CSK           41.0       31.0
# DC            35.0       13.0
# KKR           37.0       21.0
# KXIP           NaN        NaN
# MI            39.0       37.0
# RCB           47.0        1.0
# RR            43.0       33.0
# TT            45.0       33.0

# %%
df4=match.add(match2,fill_value=5)

# %%
df4
# Out:
#       Match_played  Match_won
# Name
# CSK           41.0       31.0
# DC            35.0       13.0
# KKR           37.0       21.0
# KXIP          24.0       13.0
# MI            39.0       37.0
# RCB           47.0        1.0
# RR            43.0       33.0
# TT            45.0       33.0
