# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('datasets/CarPrice_Assignment.csv')
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df.shape
# Out:
# (205, 26)

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
df.corr()['price'].sort_values(ascending=False)
# Out:
# price               1.000000
# enginesize          0.874145
# curbweight          0.835305
# horsepower          0.808139
# carwidth            0.759325
# carlength           0.682920
# wheelbase           0.577816
# boreratio           0.553173
# carheight           0.119336
# stroke              0.079443
# compressionratio    0.067984
# symboling          -0.079978
# peakrpm            -0.085267
# car_ID             -0.109093
# citympg            -0.685751
# highwaympg         -0.697599
# Name: price, dtype: float64

# %%
col = ['enginesize', 'curbweight', 'price']

# %%
data = df.loc[:,col]
data.head()
# Out:
#    enginesize  curbweight    price
# 0         130        2548  13495.0
# 1         130        2548  16500.0
# 2         152        2823  16500.0
# 3         109        2337  13950.0
# 4         136        2824  17450.0

# %%
X = data.drop(columns='price')
y = data.price
n = X.shape[1]
m = X.shape[0]

# %%
# w_init = np.random.rand(n)
# b_init = np.random.rand()
# w = w_init
# b = b_init
w = np.array([0,0])
b = 0

# %%
def f(w,b,x):
    return np.dot(x,w) + b

# %%
def compute_cost(w, b, X, y):
    y_pred = f(w,b,X.values)
    y_actual = y
    sum = np.sum(y_pred-y_actual)**2
    return sum/(2*m)

# %%
def compute_gradient(X,y,w,b):
# this function will loop m times (for each sample)
# calculate the error
# then loop n times (for each feature) to get gradient for each feature
# then get gradient for bias
# return the gradients
    dw = np.zeros(w.shape)
    db = 0
    for i in range(m):
        error = np.dot(X.values[i],w)+b - y[i]
        for j in range(n):
            dw[j] += error*X.values[i,j]
        db += error
    return dw/m, db/m

# compute_gradient(X,y)

# %%
def gradient_descent(X, y, w, b, alpha, epochs):
    cost_list = []
    
    for i in range(epochs):
        dw, db = compute_gradient(X,y,w,b)
        w = w - alpha*dw
        b = b - alpha*db
        cost_list.append(compute_cost(w,b,X,y))
        if i%10 == 0:
            print(f'epoch {i:3d}:, \tcost= {cost_list[-1]:8.2f}')
    
    return cost_list, w, b

# %%
J, new_w, new_b = gradient_descent(X, y, w, b, alpha=1, epochs=100)
# Out:
# epoch   0:, 	cost= 940625848140311746838528.00
# epoch  10:, 	cost= 44311902578484261001487458785463513492337055544745798914270813710744627378760257378942102149515039774377461093897526586667985000017521026253159924123207685111808.00
# epoch  20:, 	cost= .00
# epoch  30:, 	cost=      inf
# epoch  40:, 	cost=      inf
# C:\Users\NayanPC\AppData\Local\Temp/ipykernel_26036/1523158869.py:4: RuntimeWarning: overflow encountered in double_scalars
#   sum = np.sum(y_pred-y_actual)**2
# C:\Users\NayanPC\AppData\Local\Temp/ipykernel_26036/4073002151.py:12: RuntimeWarning: overflow encountered in double_scalars
#   dw[j] += error*X.values[i,j]
# ...

# %%
J, new_w, new_b = gradient_descent(X, y, w, b, alpha=100, epochs=100)
# Out:
# epoch   0:, 	cost= 9406261062629502017838514176.00
# epoch  10:, 	cost= 1138157591446199084972859457536.00
# epoch  20:, 	cost= 4148161139570268277796499357696.00
# epoch  30:, 	cost= 9039416905434840495571874086912.00
# epoch  40:, 	cost= 15811924889039910812486891208704.00
# epoch  50:, 	cost= 24465685090385476413791783616512.00
# epoch  60:, 	cost= 35000697509471538425386458152960.00
# epoch  70:, 	cost= 47416962146298108106269983244288.00
# epoch  80:, 	cost= 61714479000865081873650929369088.00
# epoch  90:, 	cost= 77893248073172536288722961825792.00

# %%
plt.plot(J)

# %%
print(w)
print(new_w)
# Out:
# [0 0]
# [1.97430130e+10 3.73871244e+11]
